# %% [markdown]
# <a href="https://colab.research.google.com/github/marceloallegri/MiniProjeto_MarceloAllegri_V2/blob/main/analise_exploratoria_varejo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importando Bibliotecas
import pandas as pd
import numpy as np

# %%
#Carregando Arquivo csv
file_path = "/content/Base Varejo.csv"
df = pd.read_csv(file_path)

# %%
# Mostrar informações iniciais
print("--- Informações da Base ---")
print(f"Total de registros: {df.shape[0]}")
print(f"Total de colunas: {df.shape[1]}")
print(df.dtypes)
# Out:
# --- Informações da Base ---
# Total de registros: 830000
# Total de colunas: 1
# DATA;CO_ID;CL_ID;CL_GENERO;CL_EC;CL_FHL;CL_SEG;PR_ID;PR_CAT;PR_NOME;;;;    object
# dtype: object
